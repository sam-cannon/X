# %% [markdown]
# # Prompt Engineering With Dolly
# Dolly is a language model developed by Databricks. It is a variant of the GPT-3 model, which is designed to generate human-like text based on the input it is given. Dolly has been trained on a diverse range of internet text, but it does not know specific documents or sources it was trained on.
#
# **How Dolly Works:**
# Dolly generates text by predicting the next word in a sentence. It uses the context of the input provided to it to make these predictions. For example, if you provide Dolly with the input "The sky is", it might predict the next word to be "blue". It continues generating words until it reaches a specified length or until it generates an end-of-sentence token.
#
# **Pros of Dolly:**
# 1. **Versatility:** Dolly can generate a wide variety of content, from stories and poems to technical reports and code.
# 2. **Coherency:** The text generated by Dolly is often coherent and grammatically correct, making it useful for a wide range of applications.
# 3. **Customizability:** You can guide Dolly's output by carefully crafting the input. For example, you can ask it to generate a story in the style of a specific author, or to write a poem about a specific topic.
#
# **Cons of Dolly:**
# 1. **Lack of Understanding:** Dolly doesn't understand the text it generates. It doesn't have beliefs or desires. It generates text based on patterns it learned during training.
# 2. **Inappropriate Content:** Dolly can sometimes generate inappropriate or biased content, as it learns from the data it was trained on, which includes the biases present in that data.
# 3. **Unpredictability:** It can be hard to predict what Dolly will generate, especially for longer pieces of text. It might not always generate the content you want, and might require multiple attempts to get a satisfactory output.

# %%
#imports
import warnings
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoModelWithLMHead
import re
import pandas as pd
import os
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(r"C:\Users\samuel.cannon\OneDrive - LinQuest Corporation\Desktop\decorations-generator\decorations-generator\dolly", padding_side='left')
model = AutoModelForCausalLM.from_pretrained(r"C:\Users\samuel.cannon\OneDrive - LinQuest Corporation\Desktop\decorations-generator\decorations-generator\dolly")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model
# Out:
# GPTNeoXForCausalLM(
#   (gpt_neox): GPTNeoXModel(
#     (embed_in): Embedding(50280, 2560)
#     (emb_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0-31): 32 x GPTNeoXLayer(
#         (input_layernorm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (post_attention_layernorm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (post_attention_dropout): Dropout(p=0.0, inplace=False)
#         (post_mlp_dropout): Dropout(p=0.0, inplace=False)
#         (attention): GPTNeoXAttention(
#           (rotary_emb): GPTNeoXRotaryEmbedding()
#           (query_key_value): Linear(in_features=2560, out_features=7680, bias=True)
#           (dense): Linear(in_features=2560, out_features=2560, bias=True)
#           (attention_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (mlp): GPTNeoXMLP(
#           (dense_h_to_4h): Linear(in_features=2560, out_features=10240, bias=True)
#           (dense_4h_to_h): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): GELUActivation()
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#   )
#   (embed_out): Linear(in_features=2560, out_features=50280, bias=False)
# )

# %%
tokenizer
# Out:
# GPTNeoXTokenizerFast(name_or_path='C:\Users\samuel.cannon\OneDrive - LinQuest Corporation\Desktop\decorations-generator\decorations-generator\dolly', vocab_size=50254, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['### End', '### Instruction:', '### Response:']}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<|padding|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	50254: AddedToken("                        ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50255: AddedToken("                       ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50256: AddedToken("                      ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50257: AddedToken("                     ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50258: AddedToken("                    ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50259: AddedToken("                   ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50260: AddedToken("                  ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50261: AddedToken("                 ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50262: AddedToken("                ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50263: AddedToken("               ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50264: AddedToken("              ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50265: AddedToken("             ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50266: AddedToken("            ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50267: AddedToken("           ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50268: AddedToken("          ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50269: AddedToken("         ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50270: AddedToken("        ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50271: AddedToken("       ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50272: AddedToken("      ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50273: AddedToken("     ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50274: AddedToken("    ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50275: AddedToken("   ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50276: AddedToken("  ", rstrip=False, lstrip=False, single_word=False, normalized=True, special=False),
# 	50277: AddedToken("### End", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	50278: AddedToken("### Instruction:", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	50279: AddedToken("### Response:", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
# Define the input text
input_text = "how large is the moon?"

# Encode the input text
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate a response
output = model.generate(input_ids, max_length=30, temperature=0.2, num_return_sequences=1)

# Decode the response
response = tokenizer.decode(output[0], skip_special_tokens=True)

print(response)
# Out:
# c:\Users\samuel.cannon\AppData\Local\anaconda3\envs\dexgen\lib\site-packages\transformers\generation\configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.2` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# how large is the moon?
#
# The moon is about one-third the size of the earth.
#
# The moon is about one-third

# %%
#open data file and read in contents 
with open('_AIData_JSON.txt', 'r') as file:
    contents = file.read()
    
print(contents)
# Out:
# {
#     "ID": "001",
#     "RANK": "2LT",
#     "YEAR": "2016",
#     "DEC": "AFAM",
#     "ANOMALY": 1,
#     "NARRATIVE": "During this time, the outstanding professional skill, leadership and ceaseless efforts of Lieutenant XXX resulted in significant contributions to the effectiveness and success of the Air Force's only Undergraduate Combat Systems Officer training program.  Additionally, he administered 140 practice evaluation tests in Air Education and Training Command's busiest Standardization and Evaluations Flight, pivotal to an overall 98 percent test average.  furthermore, Lieutenant XXX inspected 163 squadron flight evaluation folders and tracked 372 written exams, ensuring a 100 percent on time completion rate and identifying 183 discrepancies.  Finally, he compiled T-1A takeoff & landing data of 64 runway configurations, which streamlined student training.",
#     "TYPE1": "TR",
#     "EVAL1": [
#         "2Lt XXX is being eliminated from UCT due to Lack of Adaptability.",
#         "2LT XXX bearing, appearance, and physical fitness have been excellent during this course and while awaiting reassignment.  His professionalism will be a valuable asset for any unit to which he is"
#     ]
# }
# {
#     "ID": "002",
#     "RANK": "SRA",
#     "YEAR": "2012",
#     "DEC": "AFAM",
#     "NARRATIVE": "During this period, Sergeant XXX superbly supported Operation ENDURING FREEDOM by ensuring the accountability and processing of United States and coalition forces.  Sergeant XXXX executed the reception operations for 315,000 personnel ensuring warfighters were properly briefed and processed.  His oversit of 3,200 off base request trips with 7,000 force protection status checks ensured the safety and security of wing personnel.  Additionally, Sergeant XXX was instrumental in processing 26 reenlistment bonuses, resulting in 310,000 dollars in tax free entitlements for Air Force personnel.  Furthermore, he participated in the Koi Tash Noncommissioned Officer as part of Theater Security Cooperation Russian and English language exchange enhancing the United States and Kyrgyz Republic partnership.  Finally, his exemplary performance led to his team garnering the 376th Expeditionary Mission Support Group Team of the Month Award for November 2011.",
#     "TYPE1": "EPR",
#     "EVAL1": [
#         "- Directs spt to 6K active duty/guard/reserve/retirees/dependents at Air Force's only Joint Specialized UPT base",
#         "- Delivers procedural guidance on assignment and formal training processes to 18 group/squadron commanders",
#         "- Audits/updates MilPDS for integrity; counsels Airmen on SGLI program; customer service rep/issues ID cards",
#         "- Trains/leads deployment functions; manages Airmen in-processing actions/force shaping & retraining programs",
#         "- Located/Uploaded 10 missing evals for six promotion boards...assured mbrs rec rdy for AFPC brd w/no delay",
#         "- #1 vRED accuracy rate in AETC; scrutinized 1.3K personnel records/revised address format...99.7% accurate",
#         "- Led monthly MilPDS data review/refined process; 92% reduction in sys rejects...certified wing's data integrity",
#         "- Reorganized customer service workflow; reduced req'd visits...cut customer processing and wait-time by 50%",
#         "- Spearheaded 386 Automated Records/495 leave trans; rejects reduced by 35%; zero repeats; 38 man-hrs saved",
#         "- Implemented auto RIP delivery sys; daily products now sent directly to units; saved MPS $3.6K/300 man-hours",
#         "- Finished 60 hrs of DCAPES trng; 10 hrs of search & recovery; selected to fill joint tasking in spt OCO mission",
#         "- #1/22 team mbrs selected to attended 80 hour formal honor guard tng class; only 1 of 2 wg honor guard trainers",
#         "- Elite Silver Talon Honor Guard member; worked 18 on/off duty details...90 hours covering the tri-state region",
#         "- 1st in AETC to update 60 officer duty history/promotion board discrepancies; 3 month task completed in 2 wks",
#         "- Efficiently authorized $2M in benefits/issued 954 CACs/dep IDs; cut customer wait by 47%...avg 8 min vs 15",
#         "- Superb leader/team player; SSgt selection well deserved; first choice for NCOIC, Force Management Section!"
#     ]
# }
# {
#     "ID": "003",
#     "RANK": "SSGT",
#     "YEAR": "2013",
#     "DEC": "AFAM",
#     "NARRATIVE": "During this period, Sergeant XXX refurbished a 252,000 dollar satellite communications antenna, eliminating corrosion from 12 anchor points and restoring the system for air operations training.  His efforts prevented a one-month depot repair and saved the squadron 50,000 dollars in parts, labor, and shipping costs.  Additionally, Sergeant XXX deployed in support of Operation ENDURING FREEDOM, where he maintained two tactical satellite terminals.  He identified an unauthorized transponder and coordinated its removal, eliminating a 3 year frequency problem and facilitating air operations command and control of 44,000 combat sorties.  Finally, Sergeant XXX authored emergency transfer procedures for a remotely controlled radio communications system.  His efforts reduced system restoral time from 2 hours to 10 minutes, cementing hand over of command and control for the Arabian Gulf's air defense mission.",
#     "TYPE1": "EPR",
#     "EVAL1": [
#         "- Deploys tactical comm systems supporting offensive/defensive radar control, surveillance and airspace mgmt",
#         "- Installs/operates/maintains $22M SATCOM/$1.5M Remote Radio over Internet Protocol transmission system",
#         "- Maintains radios/configures tactical antennas on 4 Tactical Air Ops Modules weapons systems valued at $29M",
#         "- Documents workcenter repair actions/personnel trng progression using the Integrated Mx Data System database",
#         "- Prepped satellite system for OEF tskng; led 22 Amn in antenna pack up; met DEPORD 72-hr suspense in 1 day",
#         "- Overhauled $252K SATCOM antenna; excised corrosion from 12 anchor pts--saved sq $50K/1-mo depot time",
#         "- Rebuilt bad cable connector; restored amplifier function--revived 2-site fld exercise data link/trained 18 mbrs",
#         "- ID'd broken 220 volt outlet; secured mount coupling/powered 2 radio terminals--allowed $3M C3 asset turn-in",
#         "- Dedicated 20 hrs for wg detail; cleared 2K lbs trash/10 mi coastline--cemented AF/Ft Walton community ties",
#         "- Pivotal to flt's sports day cookout; led 9 Amn set up crew/coord events--boosted morale for 115 mbrs/families",
#         "- Passed humanities/information mgmt classes; 6 CLEP credits applied towards CCAF--4 crs remain to graduate",
#         "- Organized SATCOM trng; prepped antenna set up--crs certified 5 trainers/qualified 19 Amn on deploying asset",
#         "- Augmented 31 LRS; processed 94K lbs cargo/loaded C-17--supported wg's NATO Icelandic Air Policing msn",
#         "- Supervised 7 Amn; completed 23 PMIs/optimized 16 radios--facilitated 95 live msn controls/78 ops Amn trng",
#         "- Managed 4 mbrs in warehouse cleanup; ID'd 1.4K excess assets--61K lbs to DRMO/initiated sq's closure push",
#         "- Tiger Team standout; aided readiness flt/verified accuracy of 310 mobility folders/relieved backlog--promote!"
#     ],
#     "TYPE2": "EPR",
#     "EVAL2": [
#         "- Operates a $1.5M Remote Radio over Internet Protocol (RRoIP) system for radar control/airspace battle mgmt",
#         "- Maintains four $1.8M Ground Multi-band Terminals (GMT)/one $750K Quad-band Large Aperture Antenna",
#         "- Trains/sustains readiness for exercises/worldwide deployments supporting DoD/HHQ/NATO/contingency ops",
#         "- Documents mx activities using the Integrated Mx Data System and tracks mbrs' tng progression using databases",
#         "- Led 7 mbr team; ID'd/replaced faulty components--restored two radios/enabled $350K RRoIP system upgrades",
#         "- Drafted emergency radio cut over plan; penned SOP/now 10 mins vs 2 hrs--bolstered Arabian Gulf defense net",
#         "- Mended SATCOM radio link; fabricated amplifier connector--mitigated 45K square mi airspace mgmt outage",
#         "- Managed VCO prgm; coord PMIs/repairs on 29 assets--sustained $980K fleet/reliable transportation for OCO",
#         "- Maj Gruenther memorial volunteer; performed set up/tear down/transportation--1.4K attendees/honored legacy",
#         "- Devoted 10 hrs to Halloween/Warrior runs; coord teams/logistics--bolstered MWR of 500 "purple force" mbrs",
#         "- Completed speech CLEP; finished comm requirement/3 credit hrs--advanced towards CCAF degree graduation",
#         "- Attended financial mgmt seminar; gained fiscal/investment knowledge--refined expense budget/retirement goals",
#         "- Spearheaded GMT mx repair; rebuilt strut/realigned antenna--negated 3 mo depot overhaul/$4.5K replacement",
#         "- Executed COMSEC prgm; initiated 1.8K key loads/60 assets--secured OEF C3 link/garnered Team of Mo Awd",
#         "- Engineered public address install; wired 4 buildings/19 speakers--broadcast FPCON/wg battle staff directives",
#         "- Piloted inventory team; standardized accountability of 6 containers/171 items worth $2M--right choice for SSgt"
#     ]
# }
# {
#     "ID": "004",
#     "RANK": "SSGT",
#     "YEAR": "2007",
#     "DEC": "AFCM""NARRATIVE": "While deployed to Kuwait in support of Operation ENDU RING FREEDOM, Sergeant XXX provided topnotch security as escort for over 300 third country nationals on one of the largest Central Command construction projects. His unwavering leadership ensured the 12.9 million dollar venture was completed on time and without incident. In addition, Sergeant XXX helped restructure the Client Support Administration training facility by setting up computers, running cables and loading all required software. His diligent efforts increased the work center's personnel certification capability by 66 percent. Finally, as Network Training Instructor, Sergeant XXX used his advanced teclmical skills to create the Information Management Master Training Plan and personally trained over 130 Client Support and System Administrators assigned to the 4th Fighter Wing. He also developed 15 Mission Qualification Evaluations to certify the wing's Client Support Administrators to ensure compliance with Air Force and Air Combat Command Operating Instructions.",
#     "TYPE1": "EPR""EVAL1": [
#         "-Definitely a superstar and top-shelf performer--excelled at all assigned tasks and exceeded all expectations",
#         "-Deployed as Third Country National security escort in support of OPERATION ENDURING FREEDOM ",
#         "-Supervised more than 300 multinational personnel supporting 12.9 million dollar project--zero incidents ",
#         "-Noteworthy performance helped clinch success of largest Air Combat Command construction project",
#         "-Single-handedly combined base publications and records management's paper and electronic official files ",
#         "-Tremendously enhanced customer service support--reduced document search and review time by 60%",
#         "-Assisted in the restructure and upgrade of the wing information management (IM) deployment resources",
#         "-Improved IM Function readiness and ability to deploy assets within a 24-hour notice without a hitch",
#         "-Laudable efforts guaranteed the on-time delivery of official mail and parcels without one discrepancy",
#         "-Served as an entry control monitor for critical telephone switch facility following the September 11 attacks",
#         "-Prevented security violations and ensured 100 % accountability of facility personnel and equipment",
#         "-Strong effort to sharpen skills--completed more than 80 computer based training modules in three months",
#         "-Ex ertl ublished weekl official bulletins--first class product kept entire wing informed--promote now!",
#         "-Assisted Workgroup Management Program Office in revamping its computer and network training center ",
#         "-Set up computers, ran cables, loaded software--increased network certification capability 66 percent",
#         "-Meticulously sorted over 6,000 x-rays for submission to Defense Reutilization and Marketing Office",
#         "-Recycling zeal enabled silver to be reused--saved tax dollars and provided additional Air Force revenue",
#         "-Air Force ambassador--participated in many on and off-base activities during SJAFB Honor Guard duty",
#         "-An airman of standards--stron work ethic and im eccable dress and a earance-- romote below-the-zone!"
#     ],
#     "TYPE2": "EPR",
#     "EVAL2": [
#         "-Outstanding performer! SrA Aguryanov accepts all assignments and tasks without hesitation--dependable",
#         "-My #1 airman! Expertly served as Base Publications and Forms Manager; quickly grasped duties with minimal supervision--processed/published 10 publications/three forms ahead of schedule--flawless work",
#         "-Prepared Information Management deployable package in support of Operation ENDURING FREEDOM ",
#         "-Expertly directed actions to deploy three personnel/two tons of equipment to Al Udeid Air Base, Qatar",
#         "-Top Performer! Input personnel data into pre-deployment database for 160 unit personnel one week ahead of schedule--enhanced Readiness Office ability to organize/track requirements for real world deployment",
#         "-Energetic and eager--during a two month period he updated and filed SGLI forms, DD Form 93 and vaccination program in CAMS for 42 deploying personnel--quality work and dedication second to none",
#         "-Team player! Assisted Base Records manager with the staging, signing out and the destruction of records",
#         "-Exhibited superb skills while assembling 4 FW Base Bulletin--distributed to 13 squadrons throughout wing",
#         "-Sets positive example for peers--member of E.A.G.L.E.S. group--improved base quality of life programs",
#         "-Impressive! Selected for Below the Zone to SrA--chosen from 118 airmen--oromote immediately to SSgt!",
#         "-Exceptional technical skills; Base Equipment Control Officer requested him by name to assist in projects ",
#         "-Built a complete networthy computers from computers destined for turn-in without any assistance",
#         "-Great initiative! Expertly organized and revamped $500 of computer components into a storage area",
#         "-Provided superior assistance to BITC office--processed over 200 pounds of mail with zero discrepancies",
#         "-Proficient and industrious; loaded software for over 35 computers destined for reallocation to wing users",
#         "-Razor sharp airman--member of USAF Pistol Team--instructed students at local schools/colleges--oromote"
#     ],
#     "TYPE3": "EPR",
#     "EVAL3": [
#         "-Benchmark of excellence! Exemplifies the character, initiative and career field expertise to tackle any task",
#         "-Highly motivated and productive! Consistently sought-out throughout the 4th Fighter Wing",
#         "-Requested "by name" to train Information Managers for the 4th Aircraft Maintenance Squadron's First Term Airman",
#         "-Skilled IMer; Quickly stepped in to assist 4th Services Squadron with Records Management staging duties",
#         "-Prepared SF 135s, procured staging boxes and prepared mortuary files with a 14-year disposition for staging",
#         "-Hard-charger! Assumes new responsibilities with enthusiasm and zest unprecedented in a young Airman",
#         "-Staunch supporter of base/community events--eagerly volunteered 40+ hours, January through March 2004",
#         "-Sr A XXX performance speaks for itself--meticulously identified hundreds of expired file dispositions",
#         "-Selflessly initiated immediate destruction of old files; vacated staging shelf space for current file staging",
#         "-A truly superlative Airman! Attended Air Force Honor Guard Technical Training School; resulted in SrA XXX recognition as Base Honor Guard Airman of the Quarter January through March 2004",
#         "-Fountain of knowledge! Recognized expert for his vast understanding oflnformation Management",
#         "-Epitomizes core values! Displays great personal dedication, motivation and professionalism--promote to SSgt",
#         "-Integral member of Admin Comm! Trained Base Forms & Publications manager on Dreamweaver software",
#         "-Cleared a six month backlog of Seymour Johnson AFB publications awaiting posting and publication",
#         "-Always on the mark! Tremendous potential evidenced by exceptional daily performance on the toughest jobs",
#         "-Outstanding Information Manager! Provided comprehensive task certification training to supervision and peers",
#         "-Impressive time management skills ensures he always completes assigned tasks 100% accurate the first time",
#         "-SrA XXX is an outstanding professional that can be counted on anytime anyplace--promote to SSgt now!"
#     ],
#     "TYPE4": "EPR",
#     "EVAL4": [
#         "-Outstanding NCO--instructed 20 personnel to accurately perform 282 evaluation tasks with zero assistance",
#         "-Provided Network Certification training on IQT responsibilities--students ready for challenging written exam!",
#         "-Coordinated with five base agencies to support two 35 member teams--ensured network access for operation ",
#         "-Results oriented--organized the preparations for two Safety Investigation Board teams in less than two hours",
#         "-Excellent trainer--skills led to 66% of all NCC personnel mission qualification trained in less than four months",
#         "-Expeditiously implementated the flight Task Qualification Training {TQT)--from concept to program in one day",
#         "-Comprehensive 46 item TQT checklist enabled 23 personnel to be trained on 966 critical wartime tasks",
#         "-Developed new Dreamweaver webpage writing course--21 webpage managers trained on latest techniques",
#         "-Spearheaded relocation of the NCC training classroom--expertly setup network in alternate location in one day",
#         "-Guaranteed ACC provided Exchange 2003 and Server 2003 classes took place on time--20 personnel trained",
#         "-Participated in Nationwide "Make a Difference Day"--installed a shingle roof on a Habitat for Humanity house",
#         "-Diligent student--efforts led to earning 90% on end of course test; also earned over 140 credits towards CCAF",
#         "-A highly motivated NCO who thrives on providing the 4 FW outstanding customer support--promot􀁄 soonest!",
#         "-Led tiger team that ensured 15 systems were ready for Air Force Communications Agency contracted training ",
#         "-Ensured $75,000 training endeavor was successful--54 personnel effectively trained on new required skills",
#         "-Outstanding Marksman! Hand selected as a primary team member for the 2005 Air Force National Pistol Team ",
#         "-Represented the Air Force in 13 regional and national toumaments--qualified second best shot in Air Force",
#         "-Supported local Salvation Army--generously donated money and canned goods--needy citizens provided relief",
#         "-Easily any supervisor's go-to technician, definitely ready for any and all missions--promote ahead of peers!"
#     ],
#     "TYPE5": "EPR",
#     "EVAL5": [
#         "-Superior NCO and training instructor--singlehandedly trained 72 CSAs and Sys Admins assigned to the base",
#         "-Initiated online scheduling of classes through squadron's training Community of Practice--streamlined process",
#         "-Created list of 72 CBTs required for upgrade training--eliminated confusion and standardized requirements",
#         "-Developed 15 MQE tasks for certification of wing CSAs; enhanced program--took IM training to the next level",
#         "-Handpicked to support staff members during BRAC team visit and safety investigation board--setup 18 systems",
#         "-Administered ACC-mandated Special Instructions for Communicators test--93% of wing 3As tested in 2 weeks",
#         "-Worked directly with wing 3A Functional Mgr to solve 3A-related training issues; provided valuable insight",
#         "-Resourceful--procured 12 additional workstations; supported 3A Immersion Program and LSET inspectors",
#         "-Leader among peers; worked one-on-one with 2 IMers who failed their initial end of course exam--dedicated",
#         "-Coordinated A+, Dreamweaver and HTML commercial classes for 36 CSAs--increased initial user support",
#         "-Team oriented--assisted Records Manager with disposal of 400 boxes of sensitive records--cleared backlog",
#         "-Integral part of 2006 Air Force National Pistol Team; competed in 7 regional and national matches--#2 of 10",
#         "-Completed 6 hours and CCAF degree in Information Management; pursing second masters--promote now!",
#         "-Instructed over 50 web page maintainers in local Dreamweaver course--ensured compliance with standards",
#         "-Wealth of knowledge; developed e-mail and internet policy guidance for Base X--enhanced ORI capabilites",
#         "-Developed standards; major contributor in creation of wing 3A Master Training Plan--committed to excellence",
#         "-Expert marksman--trained over 300 civilian shooters at interservice small arms firing school--enhanced skills",
#         "-Recognized professional; selected 4 FW Information Manager of the Quarter, Apr - Jun 06--clear-cut choice",
#         "-Fully qualified instructor; obtained CompTIA A+ certification: always seeks to be the best--promote soonest"
#     ],
#     "TYPE6": "EPR",
#     "EVAL6": [
#         "-Exemplary NCO! Talented and decisive CSA--exactly what Air Force expects from its NCO leadership core",
#         "-Loaded software/patches for Base X as lead CSA during 4 FW Phase II ORI--led to "Outstanding" for Info Ops",
#         "-Trained and certified 61 Seymour Johnson CSAs on domain use/network security--enhanced CSA effectiveness",
#         "-Maintained immaculate CSA database--expedited after hours user access restoration and special requirements",
#         "-Sustained 42 computers in Support Flt--averted extended interruptions to multimedia's specialized equipment",
#         "-Reorganized space in IM building; cleared out dumping ground--reused + lK sq ft for ADPE and ORE work",
#         "-Gave input on CSA tmg packets for deploying 3As--prepped wing for successful future exercises/deployments",
#         "-Rekeyed locks on entire building--safeguarded FOIA, Privacy Act and Records Management information",
#         "-Provided web page tmg to Airfield Field Ops; revised a lack-luster web page--reduced clicks to flt line tmg",
#         "-Administered ACC-mandated Special Instructions for Communications test--ensured wing 100% compliant",
#         "-Led computer setup for wg Safety Investigation Boards--support allowed team to find root cause of accidents",
#         "-Unquenchable thirst for knowledge; completed 12 semester hours towards second Master of Science Degree",
#         "-Superior technical expertise and strong leadership; excels at toughest assignments--promotion to TSgt a must!",
#         "-Taught and trained all CSAs in 4 FW--his actions helped wg earn first "Excellent" ORI Phase II rating in 9 yrs ",
#         "-Recognized as "Superior Performer" by ACC IG Team Lead; received coined from ACC 3A Functional Mgr",
#         "-Setup comm for Air Traffic Systems Evaluation Program team--ensured 100% inspection of airfield systems",
#         "-Lead IMer during all Phase I and II Operational Readiness Exercises--ensured equipment and wing ORI ready",
#         "-Replaced 8-day CSA Powerpoint training process with true 5-day hands-on class--reduced class time by 38%",
#         "-Dedicated professional! Hand-picked from wg 3A pool as lead CSA trainer/mentor--promote to TSGT now!"
#     ]
# }
# {
#     "ID": "005",
#     "RANK": "1LT",
#     "YEAR": "2022",
#     "DEC": "AFAM",
#     "ANOMALY": 1,
#     "NARRATIVE": "On this day, Lieutenant XXX' quick-to-action response instincts were critical in responding to a rapidly spreading Colorado mountain wildfire. Without hesitation or regard for his own safety, he expeditiously assessed the scene and safely guided a team of eight civilian and Guardians toward ground zero to perform containment actions. Lieutenant XXX and his team depleted their water reserves and used nearby rocks and dirt to extinguish the flames by hand. Additionally, he controlled the scene by creating a blockage to stop civilian hikers from entering the unstable environment and coordinated situational reports to inbound emergency responders. For one and a half hours, Lieutenant XXX and his team fought the blaze, which continued to reignite due to high winds and Red Flag conditions. These efforts continued until local Fire Rescue personnel could traverse the mountainside and fully contain the situation. Lieutenant XXX was lauded by the Manitou Springs Fire Chief and credited with containing a 400-square-foot blaze, which endangered 320 on-site personnel and had the potential of spreading to 5,300 local residents, which would have required the activation of state and federal emergency response agencies.",
#     "TYPE1": "OPR",
#     "EVAL": [
# - Guided 18 mbrs f/Sq PEX/MQT proj; dvlp'd tests/automat'd process--postur'd 145 G's Detect-qual'd FY '23 f/new CYSs,
# - Piloted Sq MPC/PBED stratagem; planed/CC'd 3 crit msns/20 mbrs--ensured comm/evac spt f/4M Ukraine refugees,
# - BNR f/2 jt NRO/USSF pilot crs's; ID'd tng gaps/MPC/cyber intel/176 hrs/87 fix actions--pioneer'd crit jt cyber tng rqmts,
# - Manag'd CDET kt onboard; relocat'd $700K DCO crse/BSFB to COS/prim'd rqmts--enabl'd seamless crse start/80 mbrs,
# - Spearhead'd jt NRO/USSF partnership; coor'd parallel Exs/tour efforts w/DEL 26--bridg'd info gap across jt space msns,
# - Trustworthy ofr!  Managed crit unit task/projects; efforts key to Sq CGOQ/x3 & tm qrt awds--Flt CC next, then SOS,
# - Led DEL 6/DET 1 ADVON tm; 148 grads/7 crs's/onboarded CC/mng'd $3.6M UFR--spt'd SPAFORGEN cyber rqmts,
# - Built DCO tng paths/knowledge pillars; educat'd DEL 6 ldrs/IT/cyber & Ops integration--forg'd USSF 3-5 yr tng plan,
# - Drove sq/DEL 6 trng; led 7 mbrs/charted IST/IQT/AT f/cyber G's--tm achv'd 13 sq/4 DEL qtrlies & 3 sq/2 DEL annuals,
# - #1/14 first LTs in DEL; vital officer/innovator w/ample DCO/training skills/DEL 6 CGOY '21--Flt CC now, then SOS!"
#     ]
# }
# {
#     "ID": "006",
#     "RANK": "SRA",
#     "YEAR": "2008",
#     "DEC": "AFAM",
#     "ANOMALY": 1,
#     "NARRATIVE": "During this time period, Airman XXX professional skills, knowledge, and commitment to excellence were contributing factors to the success of the 302d Airlift Wing. Airman Anderson contributed to the Maintenance Group's generation of 11,757.5 mishap free hours, an OPSTEMPO three times the norm, and a mission capability rate of73.8 percent for fiscal year 2006, exceeding the AFRC standard. His technical expertise was instrumental in meeting an accelerated Isochronal Inspection schedule resulting in an unprecedented 22 code-one landings and the completion of 24 isochronal inspections in just 16 months. "
# }
# {
#     "ID": "007",
#     "RANK": "1LT",
#     "YEAR": "2013",
#     "DEC": "AFAM",
#     "ANOMALY": 0,
#     "NARRATIVE": "During this period, Lieutenant XXX tirelessly contributed critical research and project management expertise to both reactive material characterization and hardened target penetrating weapon development. Supporting the directorate's top weapon capability, he flawlessly orchestrated the material testing efforts, providing key data that enabled improvements to penetrating explosive survivability, and thus helping to place enemy hardened targets at risk globally. Lieutenant Sprinkle also provided superior project management expertise to directional blast research and development, satisfying a warfighter urgent need for a counter-improvised explosive device weapon. Finally, his ceaseless efforts in material properties research proved instrumental in identifying reactive materials that will provide future hardened target penetrating weapons with a 200 percent increase in strength.",
#     "TYPE1": "OPR",
#     "EVAL1": [
# - AAC's '12 Outstanding Support Staff Ofcr/Yr (#1/86)! Led AFRL #1 warhead mat'l test--delivered upgraded wpns,
# - Developed high-speed imaging technique--provided new diagnostic capabilities--bolstered AFLCMC's #1 wpn test,
# - Executed $100K structural materials M&S--proved 25% increase in strength--enabled next-gen global strike wpns,
# - Finalized $375K wpn R&D--incr'd directional blast 2x; reduced collateral damage--met warfighter IED-defeat rqmt,
# - Led reactive materials program--executed mat'l properties testing--doubled hard target munition penetrator strength,
# - Exceptional leader! Demonstrated technical expertise--ready for Section/CC responsibilities--send to PDE soonest,
# - Top-notch officer! Creative, leads by example--advanced multiple technologies required for next generation wpns,
# - Piloted CSOP material testing efforts--improved HDBT munitions durability--enhanced AFRL's #1 wpn capability,
# - Led $2M selectable effects wpn prgm--drove novel warhead tst series--will give warfighter dial-a-yield flexibility,
# - Standout leader & engineer! Ready for section-level ldrship & technical team lead responsibility--PDE 1st chance!
#     ]
# }
# {
#     "ID": "008",
#     "RANK": "CAPT",
#     "YEAR": "2006",
#     "DEC": "AFAM",
#     "ANOMALY": 1,
#     "NARRATIVE": "Captain XXX spearheaded and coordinated the development of a revolutionary task-based approach to counterspace training and evaluation. He also co-authored the landmark instruction that turned the concept into reality, ensuring highly realistic combat training for Commander, United States Strategic Command's counterspace forces. These efforts were instrumental toward the 21st Operations Group's 'Outstanding' rating and the 21st Space Wing's overall "Excellent" rating during the 2006 Headquarters Air Force Space Command Inspector General Operational Readiness and Unit Compliance Inspections.",
#     "TYPE1": "OPR",
#     "EVAL1": [
# -	Directs command section staff for the 50th Operations Group Commander; primary interface to eight Sq/CCs
# -	Directly supports group's 1,
#         000 personnel developing group policies necessary to accomplish the OG mission
# -	Directs focus for quality control of all OG/CC travel, correspondence, OPRs, EPRs, awards, and decorations
# -	Leads OG tracking program to ensure accurate and timely responses to wing,
#         14 AF, and HQ AFSPC taskings
# -	Commands satellite C2 operations crew of 25 space professionals in AFSPC's only multi-missions ops center
# -	Significant Additional Duties: Wing Operations Security Program Manager; CGO Council Webmaster
# -	Led ops crew thru $63M record-setting GPS launch--unequalled 11 days to ops & 2.8-meter precision for OIF
# -	Directed spin control maneuver, re-stabilized satellite--ensured precise missile waming--top 14 AF priority
# -	Wing OPSEC manager as Lt! Trained 200+ base newcomers; filled empty squadron seats--now 100% manned
# -	Rescinded obsolete wing OI; seamlessly integrated new regulation--zero discrepancies throughout transition
# -	Directed 15 thruster firings to optimize 6 satellites for theater missile warning and warfighter GPS receivers
# -	Self starter--completed rigorous 10-day practicum in joint space intel ops--honed already sharp combat savvy
# -	Led low airflow emergency actions in ops center; prevented overheat of essential $6M C2 computer systems
# -	Responded to potential satellite attack; quickly executed emergency actions--secured $365M DoD satellite
# -	Put 25-person space ops crew on warfooting for JT GUARDIAN & OEF/OIF follow through in 36 operations
#     ],
#     "TYPE2": "OPR",
#     "EVAL2": [
# -	Supervises flight of seven ops and intel specialists in USAF's first offensive counterspace (OCS) ops squadron
# -	Deploys w/15-person OCS team, $6M Counter Comms System (CCS) to support theater space superiority objs
# -	Maintains flight's combat mission ready status to ensure rapid response to theater combatant CC's requirements
# -	Develops, reviews, & recommends improvements to real-world, exercise, and training deployment processes
# -	Injects ops perspective into evaluation/operation of emerging counterspace tactics, technologies, & equipment
# -	Msn certified to employ ops capabilities and develop logistics, ops, and C2 concepts to support joint forces
# -	OCS ops expert deployed for Weapons School Msn Employment--WPS/CC laud􀀢d his efforts: "Vital support"
# -	Crew CC for Ex TERMINAL FURY '05--USPACOM's largest ex--CCS TACON shortfalls identified/resolved
# -	Sq/SPO liaison for future counter comm technology--ensured cont'd OCS flexibility--vital to space superiority
# -	Hand-picked to lead 21 SW/SE & 21 OG/OGV through Basic Mission Ready training/observations--no errors
# -	Validated CCS C2 software/infrastructure during Exercise BLUE FLAG '05--all 8 AF & 14 AF objectives met
# -	Quick study! Drafted I st-ever cert brief for newly operational system after I-month in sq--DO: "Model brief'
# -	Ex VANGUARD/CONDOR CREST crew CC--briefed deployment status to OG/CD--sq 100% wartime ready
# -	Flexible! Took msn CC reigns for historic EUCOM ex 2 weeks before start--planning/execution never faltered
# -	Manages largest COMSEC account on base as sq CRO--aced recent MAJ COM inspection--critical to msn C2
#     ],
#     "TYPE3": "OPR",
#     "EVAL3": [
# -	Supervises two personnel in selectively-manned Offensive Counterspace (OCS) training section for two units
# -	Manages, standardizes, and controls quality of training prgms for 21 OG's 14 geographically separated units
# -	Chief/primary instructor for 21 SW counterspace Operations Standardization Team and Staff Assistance Visits
# -	Serves as functional reviewer and instructor positional evaluator on 21 OG/CC-mandated ops unit inspections
# -	Supports AFSPC, AETC, and 21 SW with acquisition of equipment and simulators for OCS training activities
# -	Coordinates with AFSPC, AETC, and 14 AF on the development of key documents, policies, and instructions
# -	Developed task-based training for Counter Communications System (CCS)--enhanced OCS combat readiness
# -	Coordinated basic mission ready trng for 21 SW/CC and CV--assured solid operational understanding of CCS
# -	Led 21 OG Defensive Counterspace efforts--paved evolutionary way ahead for satellite interference mitigation
# -	Assessed 4 SPCS ops during 3-day trng deployment--verified sq's capability to deploy/employ vital wpn sys
# -	Spearheaded Operations Standardization Team inspection at 4 SPCS--validated sq's compliance w/HHQ regs
# -	Served as OCS subject-matter expert for USAFWS Mission Employment Ex--integrated OCS w/air objectives
# -	Maintained Combat Mission Ready status on CCS--ensured combat readiness to answer COCOM msn needs
# -	Performed as team chief during Space Control Team activations--ensured safe/effective wpn sys deployments
# -	Coordinated with 533 TRS on Initial Qualification Training course re-write--closed major training disconnect
#     ],
#     "TYPE4": "TR",
#     "EVAL4": [
# -	Selected as 1 of 158 Top Third Graduates in a class of 475 US students
# -	Excelled in leadership, teambuilding, problem solving, military studies, and communication
# -	Member of the Squadron Right of Line flight
# -	Right of Line award is presented to the flight ranked #1 in its squadron
# -	Ranking is based on overall flight performance in a series of competitive leadership exercises
#     ]
# }
# {
#     "ID": "009",
#     "RANK": "1LT",
#     "YEAR": "2012",
#     "DEC": "AFAM",
#     "ANOMALY": 0,
#     "NARRATIVE": "During this period, Lieutenant XXX led a Pacific Air Forces-wide computer power reduction initiative, saving the Air Force 600,000 dollars in electrical expenses by automating the shutdown of unused computers. He also guided a 1.6 million dollar server upgrade project replacing 50 end-of-life servers across the Pacific theater and resulting in a centralized patch management process for 55,000 systems. Furthermore, Lieutenant Andresen finalized 4,175 job qualification tasks, which ultimately established a benchmark for Enterprise Service Unit training across the 690th Network Support Group. Finally, he implemented network monitoring upgrades to 235 devices, strengthening situational awareness and providing network operators real-time visibility of a 650 million dollar network supporting 175,000 warfighters.",
#     "TYPE1": "TR""EVAL1": [
# -	ASBC inspires new officers and selected civilians to understand and value their roles as future air and space power leaders. Every graduate:
# -	Comprehends how the unique capabilities of air and space power support our national security policy
# -	Values the importance of personal commitment to the Air Force and to :the Profession of Arms
# -	The ASBC academic requirement is a single comprehensive fmal examination with a minimum passing score of75%
# -	Graduated from ASBC having met the academic standards, scoring 85.00% on the final examination
# -	Solid performer--succeeded in curriculum events: academics, fitness, teapibuilding, and communication
# -	Supported flight cohesion--used interpersonal skills to resolve conflicts and enhance team unity
# -	Well-rounded professional officer, consistently contributed to the flight'􀀔 efforts in the ASBC program
#     ],
#     "TYPE2": "OPR",
#     "EVAL2": [
# - Oversaw PACAF e-mail storage compliance; relocated 853 users/implemented size limits--cut svr downtime 90%
# - Directed PC power reduction initiative; enacted PC shutdown rules--saved AF $600K on FY09 IT power expenses
# - Drove $1.6M server upgrade; replaced 50 legacy servers--simplified patch mgmt & centralized security to 55K sys
# - Obtained CompTIA Security+ cert; applied skills to NetD--enhanced C2 support for 200K annual PACAF sorties
# - Guided Kunsan AB e-mail outage support; reviewed mail flow & guided T/S; restored e-mail service to 1.5K users
# - Unlimited potential! Guided resolution of 2-year-old erroneous config--regained ctrl of 2.3K sys--Flt/CC and BDE
# - Managed $200K VPN deployment to nine sites; developed SOPs/trng--secured remote access to 2K key personnel
# - Implemented Net Monitoring upgrade; added capability to 235 devices--provided real-time visibility to $400M net
# - Liaison for SCOPE EDGE visit; directed implementation of 48 net changes--closed 555 critical ntwk vulnerabilities
# - Energetic leader w/right mgmt skills; his leadership is catalyst to section success--send him BDE in-res and Flt CC
#     ],
#     "TYPE3": "OPR",
#     "EVAL3": [
# - Managed six workcenters; finalized 4,
#         175 tasks/4 duty qual trng tracks--established AF-wide benchmark for ESUs
# - Chosen Terminal Fury '10 trusted agent; sorted Red Team vs real world attacks--educated mbrs on intrusion tactics
# - Led self-inspection charge; coord'd w/Wg and groomed unit monitors within days--passed first-ever 67 NWW LCI
# - Authored unit QA OI; outlined initial qual standards for 139 mbrs--provided baseline for QA sections AFNet wide
# - Orchestrated 1st-ever IQ/MQ process; initial qualification for 30+ pipeline Amn--adopted "best practice" by 24 AF
# - Visionary cyber warrior; continually seeks process improvement/enforced standards--BDE in-res and make Flt/CC!
# - Prevented msn critical support loss; procured GSA venue/executed $2.5M contract--saved 17 jobs/PACAF network
# - Championed first unit preventive mx program; oversaw 142 fix actions/server configs--100% cyber msn readiness
# - Outstanding UFPM! Coordinated 139 fitness assessments & managed 15 PTLs--instilled AF "Fit to Fight" lifestyle
# - Energetic leader w/right management skills; his leadership is catalyst to section success--Flt/CC soonest, then BDE
#     ],
#     "TYPE4": "OPR",
#     "EVAL4": [
# - Directed 7-pers tm during emergency shutdown of 106 servers/coord'd HVAC restoration--preserved $45M equip
# - Led net ops tiger team; closed 150 vuls/strengthened security across 22 domains--defended $650M PACAF network
# - Deployed 184 days AFG; Jt Doc/Media Exploit Ctr chief; screened 170 police recruits--stopped Taliban infiltration
# - Delivered vital ops spt to CJSOTF/30 OGAs; assisted target pkgs, ID'd 8 COMISAF HVIs--terrorists eliminated
# - Oversaw all NMEC exploit equip; forensic/tech gear worth $650K--guaranteed 24/7 availability to ISAF targeteers
# - Outstanding leader/mentor; inspired Amn to 5 quarterly,
#         3 annual & 1 NAF awds--PDE in-res a must; Flt/CC ready!
# - My go-to Lt--tackled 2.7K net events; drove 99.5% ticket closure rate supporting 300 aircraft--set 99.9% net uptime
# - While deployed, processed regionally captured enemy items; 300 phones/700 SIM cards--decisive intel saved lives
# - Developed AF-1st network acct builder; auto-created 800 accts/saved 130 man-hrs--ensured perfect RED FLAG Ex
# - My #1/2 Ops Flt Lts; true professional accomplishing all tasks w/excellence; key to msn success--PDE, then Flt/CC!
#     ]
# }
# {
#     "ID": "010",
#     "RANK": "CAPT",
#     "YEAR": "2009",
#     "DEC": "AFAM",
#     "ANOMALY": 0,
#     "NARRATIVE": "Captain XXX was the pivotal player on the initial Public Affairs team that turned Secretary of Defense policy into action in support of media coverage of the Dignified Transfers of the military members killed in combat. He worked closely with senior leadership in the Department of Defense and led the effort to author the tactical media plan that resulted in picture­ perfect engagement with every significant traditional and cable news broadcast outlet in the United States, as well as the leading print and photo wire services and two of the nations most prominent newspapersm the Washington Post and the New York times. In addition to implementing this policy change that had visibility at the highest levels of the federal government, Captain Andrews served as the operations chief, where he directed all aspects of a lO􀇝person public affairs team for each media engagement inclu4ing oversight of media ground rules, briefings, pa kits, security and acce.􀈎s to the Dignified Transfer process. The result was more than 1,500 published articles and overwhelmingly positive media coverage of the number one n􀉇 item in the United States at that time. His efforts continu.e to have an indelible impact on the dignity afforded our fallen military members upon their return and the care and support for their families.",
#     "TYPE1": "OPR",
#     "EVAL1": [
# - Leader! Highly intelligent/ops focused intuitive/take-charge warrior; staunch, unwavering officer; stellar integrity
# - Polished pro--articulate leader-key PAO to HAF/3 stars! "Mike's a superior officer in every way", says AF/A1
# - Brilliant insight: PA lead for SECAF "Warrior Care" prgm--Pt man for flawless A1 POTUS/CJCS NY press event
# - Mike's an early trailblazer! Thrives/excels on Air Staff--one of the best Wingmen I've had; truly peerless ldrship
# - Trusted; wrote SECAF/DoD/IG audit & AF NSI statements; Hill testimony prep for GOs; ldrship/vision his forte!
# - Supernova in an office of superstars! Top-notch award winner! Select early for sq command, joint staff & IDE
# - Captain in tough Air Staff billet ... PAO to 3-star HAF/A1/IG/TJAG & DUSECAF, IA; proven ... SAF/PA CGOQ
# - Tactfully engaged 20 nat'l media during CSAF/SECAF firings; drafted news release, AF story told to 15M globally
# - Deftly staffed Cyber command basing letters w/8AF, HAF/LL; basing criteria clarified,
#         18 state Governors updated
# - SAF/PA's finest--elite, strong officer trusted on AF's toughest issues; absolutely ready for command then IDE!
#     ]
# }
# {
#     "ID": "011",
#     "RANK": "SRA",
#     "YEAR": "2008",
#     "DEC": "AFAM",
#     "ANOMALY": 0,
#     "NARRATIVE": "During this period, Airman XXX performed brilliantly as Maintenance Controller while deployed in support of Operation IRAQI FREEDOM. His keen oversight of 12 command and control systems enabled the precise depiction of maintenance status to key Battle Staff leadership and contributed to an outstanding 99 percent equipment up time rate. Additionally, Airman Armas' technical skills proved pivotal in maintaining a microwave radio terminal valued at over four million dollars during a Category II Unit Exercise. His expe1tise was critical to providing an unimpeded communications link that enabled annual training for 22 air battle managers.",
#     "TYPE1": "EPR",
#     "EVAL1": [
# -	Repaired microwave radio fan assembly; safeguarded $IM Command and Control (C-2) asset from damage
# -- Located part on routine visit to supply warehouse; alleviated stress on supply system; saved Air Force $605
# -	Key player in troubleshooting and maintenance of tactical satellite terminal; replaced $15K filter circuit card
# -- Supported Category I deployed radar acquisition test; allowed connectivity across $390M defense satellite
# -	Established vital microwave link in support of 33 FW Phoenix Phase II 06-01 Operational Readiness Exercise
# -- Linked C-2 data between Deployed Radar/Command Reporting Center; sustained link uptime for 96 hours
# -	Supervised Tropo Satellite Support Radio installation for deployed Radar; allowed air coverage of 240 miles
# -	Repaired exposed power wire on microwave terminal wiring harness; protected $13K equipment from damage
# -	Performed 84 peventative maintenance inspections on five end item microwave assets with total value at $6M
# -	Instrumental in protection of equipment; relocated 23 assets valued at $17M for Hurricane Katrina evacuation
# -	Supported Federal Emergency Management Agency; helped build three homes for Hurricane Katrina victims
# -	Troubleshot/replaced $12K AC converter; placed $IM microwave system to 100% readiness in 1 hour time
# -	Natural Leader; led four Airmen in $160K upgrade of Radio Frequency comm systems; promote immediately!
# -	Key in theater deployable communications/integrated communications access package for unit type code testing
# -- Utilized/responsible for $6M of legacy equipment; allowed increased end user communications by 30%
# -	Vital technician for $4M in microwave terminals in support of Category II joint unit exercise with 255 ACS
# -- Allowed training of 22 personnel; provided unimpeded communication link for annual training requirements
# -	Completed seven book career development courses within 2 months; surpassed allotted time frame by 85%
# -- Established unprecedented training benchmark for squadron personnel to achieve; promote below the zone!
#     ],
#     "TYPE2": "EPR",
#     "EVAL2": [
# -	Handpicked by sq leadership for Maintenance Control during Operation IRAQI FREEDOM (OIF) deployment
# -	Flawlessly led crew of 10 Airmen; constructed pallet for Exercise DEMON DARE 06-01; zero discrepancies
# -	Led TROPO radio team; provided training to four Airmen; achieved comm link; bested job standard by 50%
# -	Directed five-person crew during local exercise; ensured equipment mission-ready 4 days ahead of schedule
# -	Conducted Time Compliance Technical Order installation; validated upgrades; usable bandwidth raised 200%
# -	Troubleshot/repaired faulty microwave radio power supply; re-soldered power wire; saved $92K in unit funds
# -	Installed TSSR link; enabled remote radar feed from Duke Field to Eglin; executed sq core mission capability
# -	Identified/replaced faulty waveguide during Exercise DEMON DARE 06-01; restored link in under 30 minutes
# -	Expertly troubleshot tropospheric terminal wiring; replaced charred wiring; prevented $13K depot repair costs
# -	Positive AF image; volunteered 8 hours to Feed the Homeless; served meals for 37 underprivileged civilians
# -	Spearheaded 33 FW dorm party as Nomad Association representative; increased morale for over 300 Airmen
# -	Exceptional professional competence; handpicked above peers as driver/escort for General Officer's unit tour
# -	Trained six personnel on 72 core tasks; increased work center task coverage by 15%; promote above peers!
# -	Prepared 100 situation reports while deployed to Balad AB in support of OIF; supported 150 troops in contact
# -	Flawlessly relayed maintenance status to Battle Staff; 12 command/control systems; achieved 99% OIF up-time
# -	Personified excellence; 332 AEW Base Honor Guard member; performed five Balad Honor Guard ceremonies
# -	Implemented night-shift pass-on log; ensured expeditionary leadership real-time equipment maintenance status
# -	Masterfully isolated in-op TROPO radio circuit card; repaired broken modulator; saved $7K in replacement
#     ],
# ...
# - Renewed AFSC public/private partnerships; authored tech transfer delegation request--revitalized EPAs & CRADAs
# - Established cold spray IPT; cutting edge dimension repairs to 100s of acft components/parts--$2.4M saved in first yr
# - Spearheaded additive manufacturing for 3 ALCs; enabled 3D-printed plating anodes--cut mfg time 60%/hazmat 30%
# - Co-authored AFSC Innovation Strategy; drove reverse-engineering lab roadmap--rapid spt to 2K+ engrs in 7 mx gps
# - #1/19 action officers; driving organizational changes, go-to for my top innovation/tech initiatives--IDE in-res & ML!
# - Dvlp'd trng refresh for deploying engineers; solidified ABDR/DLE prgm--met 150% tasking increase of 2 COCOMs
# - Led Ctr model-based/tech data pilot; demo'd 100% data avail on 30K parts--$16B enterprise on track for 2040 vision
# - Co-chaired AFIMSC I-WEPTAC study gp; id'd PACAF/USAFE cmbt spt gap--realized adaptive basing tac-C2 plan
# - #1/44 Center EN O-4/equivs; driven ldr, implemented enterprise level strategic vision--IDE in-res a must, ML next!
# ]
# }
# {
# "ID": "040",
# "RANK": "SRA",
# "YEAR": "2021",
# "DEC": "AFAM",
# "ANOMALY": 0,
# "NARRATIVE": "During this period, Airman XXX directed four Special Assignment Airlift Missions, securing transportation of 513 billion dollars in nuclear assets to support the United States European Command. Additionally, she submitted forty COVID-19 situational reports, tracking eighteen hundred cases and 67 hundred hours of data providing the Joint Chiefs of Staff with real-time statistics for Kirtland Air Force Base. Furthermore, she executed seven Airborne Command Post missions by coordinating 756 tasks and posturing eighteen units. She maintained a positive aircraft alert status and secured 1.1 billion dollars in aircraft assets. Finally, Airman XXX coordinated a 10 hour search and rescue mission by up-channeling critical search information to aircrews and linked two wings across two installations which resulted in three lives being saved.",
# "TYPE1": "EPR",
# "EVAL1": [
# - Hand picked over peers to fill sr controller/7 lvl billet; dir'd 100+ shifts/1.5K hrs--bolstered cmd post manpwr versatility
# - Facilitated 6 OPREP/CCIR rpts; maintained 100% on-time rate for 3 MAJCOMS--kept Sr Ldrs abreast w/KAFB ops
# - Managed CP Safety prgm; sent 25 safety recall notices/ID'd 5 discrepancies--passed yrly safety inspection/0 writeups
# - Monitored 150+ FD/BDOC/WX incidents; 240 advisories/sync'd rqmts with 18 units--enriched nuclear C2 deterrence
# - Led CP Records prgm; performed 4 insp/100+ items/removed redundancies--armed C2 prsnl w/accurate msn data files
# - Dir'd 4 SAAM msns; preserved AOC/EUCOM flt rqmts amid 38% manning shortfall--sec'd trans of $513B nuc assets
# - Spearheaded fix for inop base EMNS; procured/installed GV software--emerg notifications restored for 24K base prsnl
# - Executed C2 for 256 ROM prsnl; coord'd mobility spt/facilitated transient acft--aided 100% on-time dplymnt to AOR
# - Completed 7 crses towards Emer Mgmt BA degree; earned 9 credit hrs/20 hrs toward natl EM cert--garnered 3.8 GPA
# - Vol'd 6 hours at local food pantry; distributed donated food items--provided meals f/200 families affected by pandemic
# - Submitted 40 COVID-19 rpts; tracked 1.8K cases/6.7K hrs of data f/28 units--linked ABW/CJCS w/real-time statistics
# - Executed 7 Airborne CP msns; coord'd 756 tasks w/18 units--sustained 100% alert posture/secured $1.1B in acft assets
# - Coord'd 10 hr SAR w/UH-1N crew; delivered search info/3 lives saved--earned LOA from MFM/coined by WG/CCC
# ]
# }
# {
# "ID": "041",
# "RANK": "MSGT",
# "YEAR": "2022",
# "DEC": "AFAM",
# "ANOMALY": 0,
# "NARRATIVE": "During this period, Sergeant XXX co-led the creation and execution of the United States Space Force’s inaugural Guardian Intelligence Awards Program, ensuring 800 Guardians had the opportunity for recognition of their accomplishments in support of Space Force missions and National Defense. In this vein, she drafted and staffed the headquarters’ operating instruction for the awards, ensuring the program was in-line with and abided by current Department of the Air Force instructions and the Space Force’s Guardian Ideal. Additionally, she co-led the call-for-nominees process, including outreach to Guardians still in Air Force units, resulting in the receipt of 42 nominations from 20 organizations across 10 categories. Finally, she led the service-level boarding process, overseeing panel members from units across the enterprise, ensuring a fair and equitable process to select winners.",
# "TYPE1": "EPR",
# "EVAL1": [
# - Built inaugural svc intel for space strat; 5 LOEs/32 objs for collect/tgt'g/EMS ops--chartered future f/1.5K Guardians
# - USSF intel lead for doctrine wrkg gp; selected by S2 as SME/ID'd 12 discrepancies--generated first svc-lvl 2-0 pub
# - Authored HQ-lvl pro dev plan; tm'd w/7 SELs/crypto leads f/4 intern prgms--guided SFCO internship plan/750 mbrs
# - Directorate rep for space ops policy tm; drafted OE prod/ISR lead/4-mbr tm--codified 1st space-centric ops doctrine
# - Lead for 2-lvl EPCs; 27% personnel incr/managed roster, trng rqmts,
#     5 exercises--prepped 122 staff mbrs f/crisis ops
# - S2's rep f/SDA Pivot pilot prgm; intel expert f/sprint planning & execution--enabled svc-wide CONOP/capes dvlpmt
# - Revamped space tgt'g rqmts; advisor for six SOPs/new ops & org structure--drove space tgt'g integration/3 msn areas
# - Led 3-level org review; ID'd 13 positions for civ-to-mil swap/filled 6 skill set gaps--max'd efficiency/122-mbr staff
# - Interim First Sgt for 122 mbrs; spt'd senior ofcrs/mbrs & coord'd emer response--honed crisis mgmt/resiliency skills
# - Chaired intern interview team; prepped group for 4 candidates/co-led interviews--drove buildout of HQ SF/S2 staff
# - Penned multi-svc TTPs; coord'd w/jt orgs to build 3 intel injects for ops--emphasized space competencies f/jt force
# - S2 OTTI lead; dvlp'd 3 LOEs for HQ-level plan, ISR liaison f/testing & trng rqmts--advanced 3-star's top priority
# - My tech expert!  Vetted and approved 4 new capabilities; met CCMD's urgent need for advanced target development
# - Instituted GIAP; led 7-mo surge f/'best in svc' policy,
#     10 awds--established IC recognition prgm f/USSF 918 intel profs
# ]
# }
# {
# "ID": "042",
# "RANK": "SSGT",
# "YEAR": "2007",
# "DEC": "AFAM",
# "ANOMALY": 0,
# "NARRATIVE": "During this period, Sergeant XXX was critical to the execution of an intricate thirty~two day training schedule preparing 249 Security Forces Airmen to perform a detainee operations mission in support of Operation IRAQI FREEDOM. He developed and published a training schedule ensuring all training conflicts were resolved the day prior to training and individual equipment requirements were communicated to each Airman. Additionally, Sergeant XXX planned and communicated the daily movement of a 47 vehicle convoy to and from training locations. Finally, he partnered with Army Unit Mobilization Assistance teams to monitor the status of training and equipment shortfalls; his efforts led to a robust database that ensured l 00 percent accountability of trainees and that all trainees were issued the necessary equipment for their upcoming missions. Sergeant XXX uncanny ability to build coalitions with his Army counterparts facilitated the successful training of 249 combat ready Ainnen.",
# "TYPE1": "EPR",
# "EVAL1": [
# - Deployed 214 days to Camp Bucca, Iraq, AO R's largest internment camp in support of Op IRAQI FREEDOM
# - Defended 36 convoys moving 540 troops/180 vehicles; averted hostile attacks via flawless execution of RO Es
# - Presented 43rd Military Police Combat Patch by Brigadier General McBride,
#     43rd Brigade/CC, for leadership
# - Responded to downed Navy UAV; quick actions ensured $100K asset recovered, critical information retained
# - Detained suspect of IED placement on patrol route; transported to S2 further investigation; protected lives
# - Excels under pressure! Hand-picked by Op Sup as temp flight sergeant; managed & directly sup 19 personnel
# - Apprehended drug suspect; subdued & calmed violent suspect--quick actions ensured safety of other patrolmen
# - Keen observation skills; recovered drug paraphernalia during traffic stop--removed illicit drugs from the base
# - Detained/investigated major vehicle accident; asst. traffic investigator, secured processed of critical evidence
# - Exceptional patrolman; responded to domestic assaults--secured scene/expertly deescalated volatile situation
# - Community orientated; coached McChord's 3/4 yr old T-Ball camp; instructed fundamentals of sportsmanship
# - Provided outstanding security during AMC RODEO 2007; secured 72 US/international aircraft--zero incidents
# - Exceptional NCO with unlimited abilities; continuously exceeds all performance expectations--promote now!
# - Selected for joint AF/Army raid on suspected IED safe house; found/identified possible IED making material
# - Provided rapid response/C2 during detainee up-rising; quick actions ensured zero injuries/prevented escapes
# - Conducted 2,
#     000 hours of combat patrols during increased threats; vigilance ensured safety of coalition forces
# - Prepared 18 Airmen for End of Course examinations; produced an overall 86% passing scores w/zero failures
# - Phenomenal patrolman; apprehended 3 suspected DUis; ensured safety of McChord's roadways and populace
# - Embodies the standards of leadership and excellence; eagerly assumes enormous responsibility--promote now!
# ]
# }
# {
# "ID": "043",
# "RANK": "2LT",
# "YEAR": "2006",
# "DEC": "AFAM",
# "ANOMALY": 0,
# "NARRATIVE": "During this period, Lieutenant XXX scheduled 78 aircrew and 23 support personnel for over 300 hours of training instrumental to maintaining the worldwide deployment capability of low-density high-demand, combat assets. He meticulously analyzed and corrected training programs key to the execution of a 216 thousand dollar budget. Through recovery and reuse of valuable airdrop equipment he increased squadron efficiency and enhanced training at local drop-zones. Lieutenant XXX alleviated a critical manning shortage in the consolidated support staff, where his superior organizational skills were indispensable to an innovative physical training program, reviewing over 50 awards and decorations, and successfully hosting the AF SOC Chaplain's visit.",
# "TYPE1": "OPR",
# "EVAL1": [
# - Adeptly built knowledge and conquered prerequisites for Private Pilot's license--83% on FAA written exam
# - Key player in management and execution of $216K training budget; 100% personnel trained & combat-ready
# - Created new foundation for career training folders; master folder and inspection checklist ensured accurate
# documentation, continuity of instruction, and 100% compliance with approved guidance; filled critical tng gap
# - Excellent work as holiday party POC--reserved location, food, and entertainment; SQ/CC lauded,
#     "awesome"!
# - First to volunteer! 50+ hours of heavy labor and painting key to immaculate sqd command building renovation
# - Diligently reviewed deployment reqs; ensured aviators current...leadership well-informed of readiness status
# - Incredible commitment; sqd picnic, BBQ fund raiser for ill mbr & spouse flight...huge boost to esprit de corps
# - Drop Zone Control Officer for 15+ tactical night airdrop missions; recovered mission critical airdrop supplies
# - Devoted, multi-talented workhorse; benefits of his flexibility & ingenuity have been felt throughout the 79 RQS
# - Superb flying proficiency enabled completion of three stage checks of private pilot curriculum in record time
# - Scheduled & coordinated 100+ classes for sqd members totaling 300+ hours of training--ensured 78 aviators
# received needed training and maintained combat mission ready status in anticipation of upcoming deployments
# - A+ booster club member--time/energy fundamental to successful events, key contributor to improved morale
# - Jump-started change of command--dazzling programs, invitations, reception set positive tone for entire event
# - Single-handedly managed successful aircrew trng program; crucial robust flight and TDY schedule execution
# - Critical to unrivaled success of AFSOC chaplain visit; new vitality to relationship with grp & sqd leadership
# - # 1/2 Awaiting Pilot Training (APT); future leader, soared past all expectations; will shine as brighly at UPT
# - Dedicated & resourceful, Brandon is exceptional mix of drive, talent, & intelligence ... proved invaluable to sqd
# - Overhauled aircrew training folders in preparation for grp SA V--meticulous scrutiny key to 100% accuracy
# - Lifesaver during 2-month period of critical manning in grp CSS--reviewed 50+ awards/decorations, organized
# 563 RQG/CC call, purchased new guidon; created physical trng schedule; alleviated leadership distractions
# - #1/2 APT ... most motivated I've encountered in years--groom for most challenging jobs ... SOS first opportunity
# ]
# }
# {
# "ID": "044",
# "RANK": "CAPT",
# "YEAR": "2007",
# "DEC": "AFAM",
# "ANOMALY": 0,
# "NARRATIVE": "Captain XXX was instrumental in setting the stage for the extremely successful orientation of numerous cadets and their supporting cadre to the Air Force Flight Test Center. He tirelessly integrated resources and personnel from two wings to insure maximum cadet training opportunities. Captain XXX stepped up and seamlessly led the entire effort when the lead project officer went on extended leave. His direct and meticulous support has earned the praise of all three deployed cadre leaders and their comments that this was the best organized orientation they have seen to date.",
# "TYPE1": "OPR",
# "EVAL1": [
# - Acting Sr Protestant Chaplain for 6 months--Programs expanded/attendance increased even while 62% manned
# - Gifted counselor; commanders and troops sought out his expertise in 500+ sessions--saved lives and marriages
# - Expertly supervised a junior chaplain,
#     6 civilian staff & over 70 volunteers serving 600+ in diverse programs
# - Directed largest AW ANA program in entire DoD--mentoring 150 children weekly--unparalleled care for youth
# - Crafted Funds 01 strategically-~brought sanity to 250K + funds spending/approval process--funds increased 7%
# - Readiness Guru--expertly prepired HC for ORI conducting 5 exercises; 2 staff sent to AOR; HC 100% ready
# - Studying Arabic to serve as community liaison during deployments & to build bridges with Islamic community
# - Led tremendous small group ministry with 28 home cell groups and 280 attending--sense of community soared!
# - Expertly provided ministry in a Joint environment; Chaplain to OG, MXG and Marine det--1,
#     800+ visitations
# - Trusted by Chief of Chaplains as part of elite team designing the global future of Chapel Protestant programs!
# - Praised by USAF/HC, AFMC/HC for leadership of base & staff recovering from death of the Wing Chaplain
# - Mr. Spiritual Wellness; dedicated to "whole person" balance--600+ touched at Dimensions of Wellness event
# - Frontline Supervisors Training course's expert leader; AFMC's premier suicide prevention tool--trained 850+
# - Shined as SOS All Star--Top Third Flight, Right of Line Flight, Top Third Grad, Outstanding Contributor
# - Secured $150K+ providing healing/empowering "Reintegration Retreats"--100+ military families transformed!
# - 1st choice to supervise 2 Chaplain Candidates; superb mentor/leader; giving a rock solid start to AF careers
# - Summary Court Officer for Wingi Chaplain--ensured a smooth transition while bringing comfort to family/staff
# - My #1 Chaplain! First-rate officer; send to IDE; he's already proven he's ready for Sr Program Chaplain now!
# - XXX excelled as the rock-solid cornerstone in Edwards' recognition as AFMC's #1 Small Chapel for 2006
# - Brilliantly planned and led base wide training for 60 AFROTC cadets--building tomorrow's AF leaders today
# - 1 of only 4 captains in USAF selected for IPT to design future of Protestant Chapel programs Air Force wide!
# - Led this base through the tragic deaths of Wing Chaplain and 2 Airmen; brought healing and comfort to 1000s
# - Top 1 % of CGOs in Wing! Superb leader/first choice for difficult tasks; Send to IDE/make Sr Prgm Chaplain!
# ]
# }

# %%
# Pulls each chunk of text between curly braces into a list
chunks = re.findall(r'\{([^}]+)\}', contents)

df = pd.DataFrame(chunks, columns=['text'])

# %%
# Remove unwanted characters from strings
data = [''.join(x).replace("'", '').replace('"', '').replace(':', '').replace('\n', '') for x in df['text']]

# Create the dataframe of narratives
eval_df = pd.DataFrame(data).rename(columns={0:'evaluation'})
narrative_df = pd.DataFrame(data).rename(columns={0:'narrative'})

# Extract the evaluation data from the 'evaluation' column
eval_data = eval_df['evaluation'].str.extract(r'EVAL(.*)', expand=False).str.strip()
# Extract the data between 'NARRATIVE' and 'EVAL' in each row of the dataframe
narrative_df['narrative'] = narrative_df['narrative'].str.extract(r'NARRATIVE(.*?)EVAL', expand=False).str.strip()


# Create a new dataframe with the extracted evaluation data
eval_df = pd.DataFrame(eval_data)
narrative_df = pd.DataFrame(narrative_df['narrative'])

# Extract the text between brackets in the "evaluation" column
eval_df['evaluation'] = eval_df['evaluation'].str.extract(r'\[(.*?)\]')

# %%
df_combined = pd.concat([eval_df, narrative_df], axis=1)

# Replace dashes with commas
df_combined = df_combined.replace('-', ',', regex=True)

# Remove commas at the beginning of rows
df_combined = df_combined.apply(lambda x: x.str.lstrip(','))

# %%
prompt = """
you are responsible for creating a positive summary of the person who accomplished the following tasks outlined in the text below, summarize the text in a manner that reads like an overview:\n
 ,Definitely a superstar and top,shelf performer,
,excelled at all assigned tasks and exceeded all expectations, ,Deployed as Third Country National security escort in support of OPERATION ENDURING FREEDOM ,
 ,Supervised more than 300 multinational personnel supporting 12.9 million dollar project,,zero incidents ,
   ,Noteworthy performance helped clinch success of largest Air Combat Command construction project,
     ,Single,handedly combined base publications and records managements paper and electronic official files ,
       ,Tremendously enhanced customer service support,,reduced document search and review time by 60%, 
       ,Assisted in the restructure and upgrade of the wing information management (IM) deployment resources, 
       ,Improved IM Function readiness and ability to deploy assets within a 24,hour notice without a hitch,
         ,Laudable efforts guaranteed the on,time delivery of official mail and parcels without one discrepancy, 
         ,Served as an entry control monitor for critical telephone switch facility following the September 11 attacks,
           ,Prevented security violations and ensured 100 % accountability of facility personnel and equipment,
             ,Strong effort to sharpen skills,,completed more than 80 computer based training modules in three months,
               ,Ex ertl ublished weekl official bulletins,,first class product kept entire wing informed,,promote now!, 
               ,Assisted Workgroup Management Program Office in revamping its computer and network training center ,
                 ,Set up computers, ran cables, loaded software,,increased network certification capability 66 percent,
                   ,Meticulously sorted over 6,000 x,rays for submission to Defense Reutilization and Marketing Office,
                     ,Recycling zeal enabled silver to be reused,,saved tax dollars and provided additional Air Force revenue,
                       ,Air Force ambassador,,participated in many on and off,base activities during SJAFB Honor Guard duty,
                         ,An airman of standards,,stron work ethic and im eccable dress and a earance,, romote below,the,zone!	
"""

# Encode the prompt with attention_mask
input_ids = tokenizer(prompt, return_tensors='pt', padding='max_length', truncation=True, max_length=800, return_token_type_ids=False, return_attention_mask=True)

# Generate the output
output = model.generate(input_ids['input_ids'], attention_mask=input_ids['attention_mask'], max_length=800, temperature=.5, max_new_tokens=200)

# Decode the output
response = tokenizer.decode(output[0], skip_special_tokens=True)

#remove all commas 
response = response.replace(',', '')

print(response)
# Out:
# c:\Users\samuel.cannon\AppData\Local\anaconda3\envs\ai_tools\lib\site-packages\transformers\generation\configuration_utils.py:389: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Both `max_new_tokens` (=200) and `max_length`(=800) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# you are responsible for creating a positive summary of the person who accomplished the following tasks outlined in the text below summarize the text in a manner that reads like an overview:
#
# Definitely a superstar and topshelf performer
# excelled at all assigned tasks and exceeded all expectationsDeployed as Third Country National security escort in support of OPERATION ENDURING FREEDOM
# Supervised more than 300 multinational personnel supporting 12.9 million dollar projectzero incidents
#   Noteworthy performance helped clinch success of largest Air Combat Command construction project
#     Singlehandedly combined base publications and records managements paper and electronic official files
#       Tremendously enhanced customer service supportreduced document search and review time by 60%
#       Assisted in the restructure and upgrade of the wing information management (IM) deployment resources
#       Improved IM Function readiness and ability to deploy assets within a 24hour notice without a hitch
#         Laudable efforts guaranteed the ontime delivery of official mail and parcels without one discrepancy
#         Served as an entry control monitor for critical telephone switch facility following the September 11 attacks
#           Prevented security violations and ensured 100 % accountability of facility personnel and equipment
#             Strong effort to sharpen skillscompleted more than 80 computer based training modules in three months
#               Ex ertl ublished weekl official bulletinsfirst class product kept entire wing informedpromote now!
#               Assisted Workgroup Management Program Office in revamping its computer and network training center
#                 Set up computers ran cables loaded softwareincreased network certification capability 66 percent
#                   Meticulously sorted over 6000 xrays for submission to Defense Reutilization and Marketing Office
#                     Recycling zeal enabled silver to be reusedsaved tax dollars and provided additional Air Force revenue
#                       Air Force ambassadorparticipated in many on and offbase activities during SJAFB Honor Guard duty
#                         An airman of standardsstron work ethic and im eccable dress and a earance romote belowthezone!
#
# Air Force Ambassador
#
# Superlative performance
# Single handedly combined base publications and records managements paper and electronic official files
# Supervised more than 300 multinational personnel supporting 12.9 million dollar project
# Zero incidents
# Noteworthy performance helped clinch success of largest Air Combat Command construction project
# Singlehandedly combined base publications and records managements paper and electronic official files
# Supervised more than 300 multinational personnel supporting 12.9 million dollar project
# Zero incidents
# Noteworthy performance helped clinch success of largest Air Combat Command construction project
# Singlehandedly combined base publications and records managements paper and electronic official files
# Supervised more than 300 multinational personnel supporting 12.9 million dollar project
# Zero incidents
# Noteworthy performance

# %%
df_combined.head(2)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            evaluation  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2Lt XXX is being eliminated from UCT due to Lack of Adaptability.,        2LT XXX bearing, appearance, and physical fitness have been excellent during this course and while awaiting reassignment.  His professionalism will be a valuable asset for any unit to which he is
# 1          , Directs spt to 6K active duty/guard/reserve/retirees/dependents at Air Forces only Joint Specialized UPT base,        , Delivers procedural guidance on assignment and formal training processes to 18 group/squadron commanders,        , Audits/updates MilPDS for integrity; counsels Airmen on SGLI program; customer service rep/issues ID cards,        , Trains/leads deployment functions; manages Airmen in,processing actions/force shaping & retraining programs,        , Located/Uploaded 10 missing evals for six promotion boards...assured mbrs rec rdy for AFPC brd w/no delay,        , #1 vRED accuracy rate in AETC; scrutinized 1.3K personnel records/revised address format...99.7% accurate,        , Led monthly MilPDS data review/refined process; 92% reduction in sys rejects...certified wings data integrity,        , Reorganized customer service workflow; reduced reqd visits...cut customer processing and wait,time by 50%,        , Spearheaded 386 Automated Records/495 leave trans; rejects reduced by 35%; zero repeats; 38 man,hrs saved,        , Implemented auto RIP delivery sys; daily products now sent directly to units; saved MPS $3.6K/300 man,hours,        , Finished 60 hrs of DCAPES trng; 10 hrs of search & recovery; selected to fill joint tasking in spt OCO mission,        , #1/22 team mbrs selected to attended 80 hour formal honor guard tng class; only 1 of 2 wg honor guard trainers,        , Elite Silver Talon Honor Guard member; worked 18 on/off duty details...90 hours covering the tri,state region,        , 1st in AETC to update 60 officer duty history/promotion board discrepancies; 3 month task completed in 2 wks,        , Efficiently authorized $2M in benefits/issued 954 CACs/dep IDs; cut customer wait by 47%...avg 8 min vs 15,        , Superb leader/team player; SSgt selection well deserved; first choice for NCOIC, Force Management Section!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   narrative
# 0                                                                                                                                                                                                          During this time, the outstanding professional skill, leadership and ceaseless efforts of Lieutenant XXX resulted in significant contributions to the effectiveness and success of the Air Forces only Undergraduate Combat Systems Officer training program.  Additionally, he administered 140 practice evaluation tests in Air Education and Training Commands busiest Standardization and Evaluations Flight, pivotal to an overall 98 percent test average.  furthermore, Lieutenant XXX inspected 163 squadron flight evaluation folders and tracked 372 written exams, ensuring a 100 percent on time completion rate and identifying 183 discrepancies.  Finally, he compiled T,1A takeoff & landing data of 64 runway configurations, which streamlined student training.,    TYPE1 TR,
# 1  During this period, Sergeant XXX superbly supported Operation ENDURING FREEDOM by ensuring the accountability and processing of United States and coalition forces.  Sergeant XXXX executed the reception operations for 315,000 personnel ensuring warfighters were properly briefed and processed.  His oversit of 3,200 off base request trips with 7,000 force protection status checks ensured the safety and security of wing personnel.  Additionally, Sergeant XXX was instrumental in processing 26 reenlistment bonuses, resulting in 310,000 dollars in tax free entitlements for Air Force personnel.  Furthermore, he participated in the Koi Tash Noncommissioned Officer as part of Theater Security Cooperation Russian and English language exchange enhancing the United States and Kyrgyz Republic partnership.  Finally, his exemplary performance led to his team garnering the 376th Expeditionary Mission Support Group Team of the Month Award for November 2011.,    TYPE1 EPR,

# %% [markdown]
# ## Framing the Summarization Problem as a Question & Answering Problem Instead
# When it comes to summarizing information, Dolly can certainly do the job. However, there are certain advantages to framing the summarization task as a question and answering problem instead.
#
# 1. **Specificity**: By asking a question, you can guide Dolly to focus on specific aspects of the information. This can help in generating more relevant summaries.
#
# 2. **Contextual Understanding**: Dolly is designed to understand context and generate responses accordingly. By asking questions, you can leverage this ability to get more contextually accurate summaries.
#
# 3. **Interactive**: The question and answering approach is more interactive. You can ask follow-up questions based on Dolly's responses to get deeper insights.
#
# 4. **Control**: Questions give you more control over the output. You can ask different types of questions (what, why, how, etc.) to get different perspectives on the information.
#
# In contrast, instructing Dolly to summarize something might result in a more general summary that might not focus on the aspects you're interested in. Therefore, using Dolly for question and answering can often be a more effective approach for summarizing information.

# %%
# Define the input text
# could we change the approach of the project into a question answering task instead of summarization?
input_text = "my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks 'John Directed spt to 6K active duty/guard/reserve/retirees/dependents at Air Forces only Joint Specialized UPT base, , John then Delivered procedural guidance on assignment and formal training processes to 18 group/squadron commanders' to create a glowing job review for an individual?"
# Encode the input text
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate a response
output = model.generate(input_ids, max_length=200, temperature=0.1, num_return_sequences=1)

# Decode the response
response = tokenizer.decode(output[0], skip_special_tokens=True)

print(response)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks 'John Directed spt to 6K active duty/guard/reserve/retirees/dependents at Air Forces only Joint Specialized UPT base,, John then Delivered procedural guidance on assignment and formal training processes to 18 group/squadron commanders' to create a glowing job review for an individual?
# The following are the key points I would like to highlight:
#
# John is a highly regarded leader who has a proven track record of success in building strong working relationships and delivering results for our organization. John has a proven track record of effectively leading complex, multi-disciplinary teams to deliver results for our organization. John has a proven track record of building and leading high performing teams in a fast-paced, dynamic environment. John has a proven track record of effectively leading and developing junior leaders. John has a proven track record of effectively leading and developing subordinate leaders

# %%
# Define the input text
# could we change the approach of the project into a question answering task instead of summarization?
input_text = "my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks 'John Audits/updates MilPDS for integrity; counsels Airmen on SGLI program; customer service rep/issues ID cards, , He Trains/leads deployment functions; manages Airmen in,processing actions/force shaping & retraining programs' to create a glowing job review for an individual?"
# Encode the input text
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Generate a response
output = model.generate(input_ids, max_length=200, temperature=0.1, num_return_sequences=1)

# Decode the response
response = tokenizer.decode(output[0], skip_special_tokens=True)

print(response)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks 'John Audits/updates MilPDS for integrity; counsels Airmen on SGLI program; customer service rep/issues ID cards,, He Trains/leads deployment functions; manages Airmen in,processing actions/force shaping & retraining programs' to create a glowing job review for an individual?
#
# A:
#
# You could use the following structure:
#
# John has been an integral part of MilPDS for integrity for the past 5 years, where he has been responsible for counselling Airmen on the SGLI program and managing Airmen in the processing actions force shaping and retraining programs.
#
# John has also been a customer service representative for the past 5 years, where he has assisted Airmen with their ID cards.

# %% [markdown]
# ## Chaining Models for Batches of Evaluation Bullet Points
# Performing batch inference has several advantages over feeding Dolly a single, long prompt:
#
# 1. **Efficiency**: Batch inference allows the model to process multiple inputs at once, which can be more efficient than processing a single long input. This is especially true for models that are designed to take advantage of parallel processing capabilities of modern hardware like GPUs.
#
# 2. **Memory Management**: Long prompts may exceed the model's maximum sequence length (the maximum number of tokens that the model can handle in a single input). In such cases, the prompt needs to be truncated or split into smaller parts, which might affect the context and the quality of the generated output. On the other hand, batch inference can handle larger amounts of data without running into these issues.
#
# 3. **Quality of Output**: When processing a single long prompt, the model might lose context as it generates output, especially if the prompt is near or exceeds the model's maximum sequence length. With batch inference, each input is shorter, allowing the model to maintain better context and potentially produce higher quality output.
#
# 4. **Speed**: Batch inference can be faster than single inference, especially on hardware that supports parallel processing. This is because the time taken to load the model and perform other setup tasks is amortized over multiple inputs.
#
# Therefore, for large-scale tasks, batch inference is generally a better choice than feeding a single, long prompt to the model.

# %%
def generate_reviews(ticks_list, model, tokenizer):
    """
    Generate job reviews based on a list of ticks.

    Args:
        ticks_list (list): A list of ticks containing specific information.
        model: The model used for generating the reviews.
        tokenizer: The tokenizer used for encoding the input text.

    Returns:
        pandas.DataFrame: A DataFrame containing the generated job reviews.
    """

    # Suppress warnings
    warnings.filterwarnings("ignore")

    # Initialize an empty list to store the reviews
    reviews = []

    # Iterate over the ticks
    for phrase in ticks_list:

        # Format the input text
        input_text = f"my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks '{phrase}' to create a glowing job review for an individual?"

        # Encode the input text
        input_ids = tokenizer.encode(input_text, return_tensors="pt")

        # Generate a response
        output = model.generate(input_ids, max_length=250, temperature=0.1, num_return_sequences=1)

        # Decode the response
        response = tokenizer.decode(output[0], skip_special_tokens=True)

        # Append the response to the reviews list
        reviews.append(response)

    # Convert the reviews list to a pandas DataFrame and return it
    return pd.DataFrame(reviews, columns=['Review'])


# Usage:
ticks_list = ["John Audits/updates MilPDS for integrity; counsels Airmen on SGLI program; customer service rep/issues ID cards, , He Trains/leads deployment functions; manages Airmen in processing actions/force shaping & retraining programs",
              "John Directed spt to 6K active duty/guard/reserve/retirees/dependents at Air Forces only Joint Specialized UPT base, , Delivered procedural guidance on assignment and formal training processes to 18 group/squadron commanders"]

df = generate_reviews(ticks_list, model, tokenizer)

df
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Review
# 0  my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks 'John Audits/updates MilPDS for integrity; counsels Airmen on SGLI program; customer service rep/issues ID cards,, He Trains/leads deployment functions; manages Airmen in processing actions/force shaping & retraining programs' to create a glowing job review for an individual?\n\nA:\n\nYou could use the following structure:\n\nJohn has been an integral part of the MilPDS team for many years, and has played a key role in the success of the organization.  His contributions have helped to ensure the integrity of the SGLI program, and has helped to ensure that Airmen receive the best customer service possible.  John has also been a strong advocate for the use of ID cards, and has helped to ensure that all Airmen receive the necessary documentation to participate in the SGLI program.  John has also been a strong advocate for the use of force shaping and retraining programs, and has helped to ensure that all Airmen receive the necessary support to succeed in these programs.  John has also been a strong advocate
# 1                                                     my boss has tasked me with writing a job review, how could I summarize the specific information contained in ticks 'John Directed spt to 6K active duty/guard/reserve/retirees/dependents at Air Forces only Joint Specialized UPT base,, Delivered procedural guidance on assignment and formal training processes to 18 group/squadron commanders' to create a glowing job review for an individual?\n\nA:\n\nI would summarize the specific information contained in the ticks by using bullet points.\n\nJohn Directed spt to 6K active duty/guard/reserve/retirees/dependents at Air Forces only Joint Specialized UPT base,\n\nThis could be summarized as follows:\n\nJohn directed Specialist to conduct UPT for 6,000 active duty, guard, reserve, and retirees, and their dependents at Air Forces only Joint Specialized UPT base.\n\nDelivered procedural guidance on assignment and formal training processes to 18 group/squadron commanders.\n\nThese 18 group/squadron commanders received guidance on how to conduct UPT for 18,000 active duty, guard, reserve, and retirees, and their dependents at Air

# %%
def process_reviews(df):
    """
    Process the reviews in the given DataFrame.

    Args:
        df (pandas.DataFrame): The DataFrame containing the reviews.

    Returns:
        pandas.DataFrame: The processed DataFrame with the reviews.

    This function performs several operations on the reviews in the DataFrame:
    1. Removes all text occurring before the first question mark, ensuring that the prompt is not returned.
    2. Removes new line characters from each row in the 'Review' column.
    3. Removes text that occurs after the final period, to avoid partial sentences.
    4. Removes duplicated sentences in each review.
    5. Removes text that occurs prior to the final colon.
    6. Concatenates the rows in the 'Review' column to form one row.

    The processed DataFrame is returned with the updated 'Review' column.

    """

    #remove all text occuring before the first question mark, ensuring we are not returning the prompt
    df['Review'] = df['Review'].apply(lambda x: x.split('?', 1)[-1] if '?' in x else x)

    # Remove new line characters from each row in df['Review']
    df['Review'] = df['Review'].str.replace('\n', ' ')

    # Remove text that occurs after the final period - do not want partial sentences
    df['Review'] = df['Review'].apply(lambda x: '.'.join(x.rsplit('.', 1)[0:1]) + '.')

    #remove text that occurs prior to final colon
    df['Review'] = df['Review'].apply(lambda x: x.split(':')[-1].strip() if ':' in x else x)


    #remove duplicated sentences in review
    def remove_duplicate_sentences(review):
        # Split the review into sentences
        sentences = re.split('(?<=[.!?]) +', review)
        # Initialize an empty list to store the unique sentences
        unique_sentences = []
        # Iterate over the sentences
        for sentence in sentences:
            # If the sentence is not in the list of unique sentences, add it
            if sentence not in unique_sentences:
                unique_sentences.append(sentence)
        # Join the unique sentences back together and return the result
        return ' '.join(unique_sentences)

    # Apply the function to each review
    df['Review'] = df['Review'].apply(remove_duplicate_sentences)

    # Concatenate the rows in df['Review'] together to form one row
    df_concatenated = pd.DataFrame([df['Review'].str.cat(sep=' ')], columns=['Review'])
    
    return df_concatenated

process_reviews(df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Review
# 0  John has been an integral part of the MilPDS team for many years, and has played a key role in the success of the organization. His contributions have helped to ensure the integrity of the SGLI program, and has helped to ensure that Airmen receive the best customer service possible. John has also been a strong advocate for the use of ID cards, and has helped to ensure that all Airmen receive the necessary documentation to participate in the SGLI program. John has also been a strong advocate for the use of force shaping and retraining programs, and has helped to ensure that all Airmen receive the necessary support to succeed in these programs. John directed Specialist to conduct UPT for 6,000 active duty, guard, reserve, and retirees, and their dependents at Air Forces only Joint Specialized UPT base. Delivered procedural guidance on assignment and formal training processes to 18 group/squadron commanders.
